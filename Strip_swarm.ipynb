# %%
import seaborn as sns
import numpy as np

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
sns.pairplot(flights)

# %%
sns.distplot(flights['passengers'])

# %%
sns.distplot(flights['passengers'],kde = False)

# %%
sns.jointplot(x='year',y='passengers',data=flights)

# %%
sns.jointplot(x='year',y='passengers',data=flights,kind = 'reg')

# %%
sns.jointplot(x='year',y='passengers',data=flights,kind = 'hex')

# %%
sns.barplot(x ='year',y='passengers',data=flights,estimator=np.mean)

# %%
sns.barplot(x ='year',y='passengers',data=flights,estimator=np.max)

# %%
sns.barplot(x ='month',y='passengers',data=flights,estimator=np.max)

# %%
sns.barplot(x ='year',y='passengers',data=flights,estimator=np.mean,hue = 'month')

# %%
sns.countplot(x='year',data=flights,hue='month')

# %%
sns.boxplot(x='year',y='passengers',data=flights)

# %%
sns.boxplot(x='month',y='passengers',data=flights)

# %%
sns.violinplot(x='year',y='passengers',data=flights)

# %%
sns.violinplot(x='month',y='passengers',data=flights)

# %%
sns.stripplot(x='month',y='passengers',data=flights)

# %%
sns.swarmplot(x='year',y='passengers',data=flights)

# %%
sns.stripplot(x='year',y='passengers',data=flights)

# %%
sns.heatmap(flights.corr(),annot=True)
